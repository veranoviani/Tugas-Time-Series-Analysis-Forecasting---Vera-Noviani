# %% [markdown]
# <a href="https://colab.research.google.com/github/veranoviani/Tugas-Time-Series-Analysis-Forecasting---Vera-Noviani/blob/main/Time_Series_Basic_Day_12_Vera_Noviani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install dan Load Packages

# %%
# utilities packages
import datetime

# data wrangling and transformation package
import numpy as np
import pandas as pd
import statsmodels.api as sm

# data visualization package
import matplotlib.pyplot as plt
import seaborn as sns

# time series modeling
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot 
# !pip install sktime

# !pip install numpy

# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import data
df_1 = pd.read_csv("task_1_1.csv")
df_2 = pd.read_csv("task_1_2.csv")
df_3 = pd.read_csv("task_1_3.csv")
df_4 = pd.read_csv("task_1_4.csv")
df_5 = pd.read_csv("task_1_5.csv")
df_6 = pd.read_csv("task_1_6.csv")
df_7 = pd.read_csv("task_1_7.csv")
df_8 = pd.read_csv("task_1_8.csv")
df_9 = pd.read_csv("task_1_9.csv")
df_10 = pd.read_csv("task_1_10.csv")

# %%
# uji stationer
# define adf_test function
def adf_test(timeseries):
    print("Results of Dickey-Fuller Test:")
    dftest = adfuller(timeseries, autolag="AIC")
    dfoutput = pd.Series(
        dftest[0:4],
        index=[
            "Test Statistic",
            "p-value",
            "#Lags Used",
            "Number of Observations Used",
        ],
    )
    for key, value in dftest[4].items():
        dfoutput["Critical Value (%s)" % key] = value
    print(dfoutput)

# %% [markdown]
# # No 1

# %%
df_1 = df_1.set_index("index")
df_1.head()
# Out:
#           value
# index
# 101    1.323913
# 102    1.197747
# 103   -0.951691
# 104    1.904784
# 105   -0.551699

# %%
# create line plot
df_1.plot()

# %%
plot_acf(df_1).set_size_inches((14,5));

# %%
plot_pacf(df_1).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# Dari plot ACF dan PACF sama-sama tidak membentuk lag maka dapat dikatakan model tersebut white noise (0,0,0)

# %% [markdown]
# # No 2

# %%
df_2 = df_2.set_index("index")
df_2.head()
# Out:
#           value
# index
# 101    2.362450
# 102    3.849367
# 103    2.421574
# 104    5.052382
# 105    4.103413

# %%
# create line plot
df_2.plot()

# %%
plot_acf(df_2).set_size_inches((14,5));

# %%
plot_pacf(df_2).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# Dari plot acf membentuk pola exponential decay yang berarti dapat kita abaikan sementara pola pacf terdapat lag yang signifikan di lag 1.
# Maka dapat dikatakan model yang terbentuk ialah AR(1)

# %% [markdown]
# # No 3

# %%
df_3 = df_3.set_index("index")
df_3.head()
# Out:
#           value
# index
# 101   -1.405059
# 102    0.471055
# 103   -0.006376
# 104    1.030057
# 105    0.207344

# %%
# create line plot
df_3.plot()

# %%
plot_acf(df_3).set_size_inches((14,5));

# %%
plot_pacf(df_3).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
adf_test(df_3)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.791928
# p-value                         0.000056
# #Lags Used                      3.000000
# Number of Observations Used    96.000000
# Critical Value (1%)            -3.500379
# Critical Value (5%)            -2.892152
# Critical Value (10%)           -2.583100
# dtype: float64

# %% [markdown]
# 1.Plot series tidak menunjukan sebuah trend dan dari hasil uji dicky fuller trend telah stasioner.
#
# 2.Tidak terdapat lag pada acf dan pacf, dilihat dari plotnya juga tidak menunjukkan adanya pola tertentu, sehingga dapat dikatakan model yang sesuai adalah white noise atau ARIMA (0,0,0)

# %% [markdown]
# # No 4

# %%
df_4 = df_4.set_index("index")
df_4.head()
# Out:
#            value
# index
# 1 Jan  14.346754
# 1 Feb  14.877385
# 1 Mar  16.630073
# 1 Apr  18.742186
# 1 Mei  17.657716

# %%
plot_acf(df_4).set_size_inches((14,5));

# %%
plot_pacf(df_4).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# Dari plot acf membentuk pola exponential decay yang berarti dapat kita abaikan sementara pola pacf terdapat significant di lag 2.
# Maka dapat dikatakan model yang terbentuk ialah AR(2)

# %% [markdown]
# # No 5

# %%
df_5.head()
# Out:
#    index     value
# 0  1 Jan  3.010220
# 1  1 Feb  0.500811
# 2  1 Mar  0.430380
# 3  1 Apr  3.807056
# 4  1 Mei  1.347951

# %%
df_5 = df_5.drop("index",axis=1)

# %%
df_5.plot()

# %%
plot_acf(df_5,lags=40).set_size_inches(14,5);

# %%
plot_pacf(df_5).set_size_inches((14,5));
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
adf_test(df_5)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  1.965343
# p-value                         0.998626
# #Lags Used                     12.000000
# Number of Observations Used    87.000000
# Critical Value (1%)            -3.507853
# Critical Value (5%)            -2.895382
# Critical Value (10%)           -2.584824
# dtype: float64

# %% [markdown]
# 1.Trend pada data adalah trend naik, dari hasil uji adf fuller menunjukkan tidak stasioner.
#
# 2.Dari ploat acf terdapat pola exponential decay sehingga dapat diabaikan, sedangkan dari plot pacf membentuk significant pada lag 3.
#
# 3.Karena belum stationer maka perlu dilakukan differencing

# %%
#difference orde 1
df_5_ord_1 = df_5.diff().dropna()
(df_5_ord_1).plot()

# %%
plot_acf(df_5_ord_1).set_size_inches(14,5);

# %%
plot_pacf(df_5_ord_1).set_size_inches(14,5);
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
adf_test(df_5_ord_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.979359
# p-value                         0.036867
# #Lags Used                     12.000000
# Number of Observations Used    86.000000
# Critical Value (1%)            -3.508783
# Critical Value (5%)            -2.895784
# Critical Value (10%)           -2.585038
# dtype: float64

# %% [markdown]
# 1.Data setelah diferencing orde 1 sudah tidak memiliki trend naik, berdasarkan uji dicky fuller trend telah staioner.
#
# 2.Plot acf tidak mengalami exponential decay dan membentuk pola significant pada lag 1, sedangkan plot pacf menunjukkan significant pada lag 3, sehingga dapat dikatakan model yang sesuai adalah ARIMA (3,1,1)

# %% [markdown]
# # No 6

# %%
df_6.head()
# Out:
#    index     value
# 0  1 Jan  0.183993
# 1  1 Feb  1.712356
# 2  1 Mar  2.761235
# 3  1 Apr  2.977488
# 4  1 Mei  1.681076

# %%
df_6.plot()

# %% [markdown]
# Terlihat bahwa trend meningkat dan mengalami ketidak stasioner pada rata rata sehingga pelu dilakukan transformasi

# %%
#transformasi akar kuadrat
(np.sqrt(df_6)).plot()

# %% [markdown]
# Dengan melakukan transformasi akar kuadrat terlihat data memiliki rata rata yang stasioner sehingga transformasi akar kuadrat akan digunakan

# %%
df_6_trs = np.sqrt(df_6)

# %%
plot_acf(df_6_trs,lags=40).set_size_inches(14,5);

# %%
plot_pacf(df_6_trs,lags=40).set_size_inches(14,5);
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
adf_test(df_6_trs)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.745293
# p-value                         0.003519
# #Lags Used                     12.000000
# Number of Observations Used    87.000000
# Critical Value (1%)            -3.507853
# Critical Value (5%)            -2.895382
# Critical Value (10%)           -2.584824
# dtype: float64

# %% [markdown]
# Dilihat dari data yang telah di transform uji dickey fuller test menjadi stationary dan dilihat dari plot acf yang membentuk exponential decay dan plot pacf membentuk significant di lag ke 3. Maka dari itu pola trend membentuk AR(3)

# %% [markdown]
# # No 7

# %%
df_7.plot()

# %% [markdown]
# Dilihat dari trend data tersebut memiliki kecendrungan non stationary dan harus di lakukan tranformasi

# %%
#transformasi dengan differensiasi
df_7_ord_1 = df_7.diff().dropna()
(df_7_ord_1).plot()

# %% [markdown]
# Setelah dilakukan differensiasi orde 1, terlihat bahwa data tidak lagi memiliki non stationarity pada rata rata

# %%
plot_acf(df_7_ord_1).set_size_inches(14,5);

# %%
plot_pacf(df_7_ord_1).set_size_inches(14,5);
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
adf_test(df_7_ord_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.681461
# p-value                         0.851493
# #Lags Used                     11.000000
# Number of Observations Used    87.000000
# Critical Value (1%)            -3.507853
# Critical Value (5%)            -2.895382
# Critical Value (10%)           -2.584824
# dtype: float64

# %% [markdown]
# Dari uji dckey fuller data belum stationer sehingga perlu dilakukan differencing orde 2

# %%
df_7_ord_2 = df_7_ord_1.diff().dropna()

(df_7_ord_2).plot()

# %%
adf_test(df_7_ord_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.001806e+01
# p-value                        1.707861e-17
# #Lags Used                     1.000000e+01
# Number of Observations Used    8.700000e+01
# Critical Value (1%)           -3.507853e+00
# Critical Value (5%)           -2.895382e+00
# Critical Value (10%)          -2.584824e+00
# dtype: float64

# %% [markdown]
# Dengan melakukan differencing orde 2, data telah stationer berdasarkan uji dicky fuller

# %%
plot_acf(df_7_ord_2).set_size_inches(14,5);

# %%
plot_pacf(df_7_ord_2).set_size_inches(14,5);
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# Dari hasil acf terbentuk pola significant yang  terjadi pada lag 2 dan pacf terjadi pada lag 4 sehingga model yang sesuai adalah ARIMA(4,2,2)

# %% [markdown]
# # No 8

# %%
df_8 = df_8.drop("index",axis=1)

# %%
(df_8).plot()

# %%
plot_acf(df_8).set_size_inches(14,5)

# %%
plot_pacf(df_8).set_size_inches(14,5)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
adf_test(df_8)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.183192
# p-value                         0.020978
# #Lags Used                      2.000000
# Number of Observations Used    96.000000
# Critical Value (1%)            -3.500379
# Critical Value (5%)            -2.892152
# Critical Value (10%)           -2.583100
# dtype: float64

# %% [markdown]
# 1.trend data telah stationer berdasarkan uji dicky fuller
#
# 2.terdapat pola exponential decay pada acf, sedangkan plot pacf tidak menunjukkan pola tertentu dan memiliki significant pada lag 1 sehingga model yang sesuai adalah AR(1)

# %% [markdown]
# # No 9

# %%
df_9 = df_9.drop("index",axis=1)

# %%
(df_9).plot()

# %%
adf_test(df_9)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.815688
# p-value                          0.000051
# #Lags Used                       1.000000
# Number of Observations Used    506.000000
# Critical Value (1%)             -3.443340
# Critical Value (5%)             -2.867269
# Critical Value (10%)            -2.569821
# dtype: float64

# %%
plot_acf(df_9).set_size_inches(14,5)

# %%
plot_pacf(df_9).set_size_inches(14,5)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# 1.Trend telah stationer berdasarkan uji dickey fuller
#
# 2.Terdapat pola exponensial decay pada plot acf sehingga dapat diabaikan,sedangkan pada plot pacf tidak menunjukkan adanya pola tertentu dan membentuk significant pada lag 2, sehingga model yang sesuai adanya AR(2)

# %% [markdown]
# # No 10

# %%
df_10 = df_10.drop("index",axis=1)

# %%
df_10.plot()

# %%
adf_test(df_10)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.112777
# p-value                          0.000922
# #Lags Used                       5.000000
# Number of Observations Used    144.000000
# Critical Value (1%)             -3.476598
# Critical Value (5%)             -2.881829
# Critical Value (10%)            -2.577589
# dtype: float64

# %%
plot_acf(df_10).set_size_inches(14,5)

# %%
plot_pacf(df_10).set_size_inches(14,5)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# 1. Data telah staioner melalui uji dickey fuller
#
# 2. Berdasarkan plot acf membentuk korelasi significant pada lag 1 dan terdapat pola sinusoidal dumped pada plot pacf sehingga dapat diabaikan, sehingga model yang cocok adalah MA(1)
